# %% [markdown]
# # Irony detection using Bi-LSTM
#
# ```
# En este experimento se probó usar los caracteres como elementos únicos de este modo detectar por ejemplo si usar la combinación de caracteres hola o 'en serio' se pueda distinguir si es una oración irónica o no.
#
# ```
# Primero  se añadiran las bibliotecas necesarias que se usaran en el código de este notebook.

# %%
import pickle
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.python.keras.layers import Input, LSTM, Bidirectional, Dense, Embedding, Dropout
from google.colab import files
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Después se leerán los vectores que se prepocesaron usando el código que dice preprocesamiento.py

# %%
def LoadData(archPkl,maxlen,max_features):
  # Load data
  (x_train, y_train),(x_test,y_test)= pickle.load(open(archPkl,'rb'))
  # Reverse sequences
  x_train = [x[::-1] for x in x_train]
  x_test = [x[::-1] for x in x_test]

  # Pad sequences
#   print(x_train[0])
  x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
  x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
#   print(x_train[0])
#   x_train=np.array(x_train)
#   x_test=np.array(x_test)
  
  return (x_train, y_train),(x_test,y_test)

# %% [markdown]
# Después se realizará la arquitectura de la red neuronal.

# %%
def make_model(max_features,batch_size=None):
    tf.keras.backend.clear_session()
    source = Input(shape=(maxlen,), batch_size=batch_size, dtype=tf.int32, name='Input')
    embedding = Embedding(input_dim=max_features, output_dim=128, name='Embedding')(source)
    lstm = Bidirectional(LSTM(200, name = 'LSTM'), name='Bidirectional')(embedding)
    dropout=Dropout(0.5,name="Dropout")(lstm)
    predicted_var = Dense(1, activation='sigmoid', name='Output')(dropout)
    model = tf.keras.Model(inputs=[source], outputs=[predicted_var])
    model.compile(
            optimizer= tf.train.RMSPropOptimizer(learning_rate=0.001),
            loss='binary_crossentropy',
            metrics=['acc'])
    model_json = model.to_json()
    with open(base+"/Modelo.json","w") as json_file:
      json_file.write(model_json)
    return model

# %% [markdown]
# Ahora se entrenará el modelo usando los TPU que se puden usar gracias a Google.

# %%
import os
import time

def trainModel(training_model,x_train,y_train,x_test,y_test,weights):
  TPU_WORKER = 'grpc://' + os.environ['COLAB_TPU_ADDR']
  tf.logging.set_verbosity(tf.logging.INFO)
  # this line is to don't print warnings and info that tf use by default
  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
  tf.logging.set_verbosity(tf.logging.ERROR)
  
  tpu_model = tf.contrib.tpu.keras_to_tpu_model(
      training_model,
      strategy=tf.contrib.tpu.TPUDistributionStrategy(
          tf.contrib.cluster_resolver.TPUClusterResolver(TPU_WORKER)))

  tpu_model.summary()

  start_time = time.time()

  history = tpu_model.fit(x_train, y_train,
                      epochs=15,
                      batch_size=32 * 8,
                      validation_data=[x_test,y_test])
  tpu_model.save_weights('./tpu_model.h5', overwrite=True)
  # !cp ./tpu_model.h5 {weights}
  print("--- %s seconds ---" % (time.time() - start_time))
  return tpu_model

# %% [markdown]
# Por último se evalua el módelo y se imprime la gráfica ROC

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score,precision_score,f1_score,roc_curve,auc
import numpy as np
import matplotlib.pyplot as plt
import IPython
IPython_default = plt.rcParams.copy()
# # use a gray background
    
# # control face and edge color of histogram
# ax.hist(x, edgecolor='#E6E6E6', color='#EE6666');

def evaluate(x_test,y_test,inferencing_model):
  
  inferencing_model.load_weights('./tpu_model.h5')
  
  y_pred=inferencing_model.predict(x_test,verbose=1,batch_size=32)
  fpr, tpr, thresholds = roc_curve(y_test.astype(float),y_pred )
  y_pred=np.array([int(i) for i in map(np.rint,y_pred)])

  y_test=np.array([int(i) for i in map(np.rint,y_test)])
  # 	for i in range(15):
  # 		print("Test: ",y_test[i])
  # 	# print(y_test)
  print("accuracy ",accuracy_score(y_test,y_pred))
  print("Matriz de confusión ",confusion_matrix(y_test,y_pred))
  print("Recall ",recall_score(y_test,y_pred,average='binary'))
  print("Precision ",precision_score(y_test,y_pred,average='binary'))
  print("F1-score ",f1_score(y_test,y_pred,average='binary'))
  roc_auc=auc(fpr,tpr)
  plt.figure( figsize=(8, 6))
  ax = plt.axes(facecolor='#E6E6E6')
  ax.set_axisbelow(True)

  # draw solid white grid lines
  plt.grid(color='w', linestyle='solid')

#   # hide axis spines
#   for spine in ax.spines.values():
#       spine.set_visible(False)

#   # hide top and right ticks
#   ax.xaxis.tick_bottom()
#   ax.yaxis.tick_left()

#   # lighten ticks and labels
#   ax.tick_params(colors='gray', direction='out')
#   for tick in ax.get_xticklabels():
#       tick.set_color('gray')
#   for tick in ax.get_yticklabels():
#       tick.set_color('gray')
  plt.plot([0, 1], [0, 1], 'k--')
  plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate',fontsize="14")
  plt.ylabel('True Positive Rate',fontsize="14")
  plt.legend(loc="lower right",fontsize='12')
  plt.show()
  return fpr,tpr

# %%
base="/content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/"
basePesos="/content/drive/My\ Drive/Colab\ Notebooks/DeteccionDeIronia/Experimento2/Pesos/"
baseVect=base+"Vectores/"
ListVect=[baseVect+"vectoresSet{0}_g1.pkl".format(i) for i in range(5)]
ListWeig=[basePesos+"weights{0}_g1.hd5".format(i) for i in range(5)]
# Number of words to consider as features
max_features = 200000
# Cut texts after this number of words (among top max_features most common words)
maxlen = 200
print(baseVect+"\n"+basePesos)
print("\n".join(ListVect))
# Out:
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/
# /content/drive/My\ Drive/Colab\ Notebooks/DeteccionDeIronia/Experimento2/Pesos/
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet0_g1.pkl
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet1_g1.pkl
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet2_g1.pkl
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet3_g1.pkl
# /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet4_g1.pkl

# %% [markdown]
# Ahora necesitamos aplicarlo para cada uno de nuestros vectores ya preprocesados.

# %%
# %matplotlib inline
vects=ListVect[0]
weights=ListWeig[0]
print("-------------Set {0}-------------".format(vects))
model=make_model(max_features)
(x_train, y_train),(x_test,y_test)=LoadData(vects,maxlen,max_features)  
tpu_model=trainModel(model,x_train,y_train,x_test,y_test,weights)
fpr,tpr=evaluate(x_test,y_test,model)
# Out:
# -------------Set /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet0_g1.pkl-------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 200)               0
# _________________________________________________________________
# Embedding (Embedding)        (None, 200, 128)          25600000
# _________________________________________________________________
# Bidirectional (Bidirectional (None, 400)               526400
# _________________________________________________________________
# Dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 401
# =================================================================
# Total params: 26,126,801
# Trainable params: 26,126,801
# Non-trainable params: 0
# _________________________________________________________________
# Train on 61224 samples, validate on 15306 samples
# Epoch 1/15
# 61224/61224 [==============================] - 100s 2ms/sample - loss: 0.3845 - acc: 0.8881 - val_loss: 0.3172 - val_acc: 0.8994
# Epoch 2/15
# 61224/61224 [==============================] - 38s 613us/sample - loss: 0.3086 - acc: 0.9024 - val_loss: 0.3017 - val_acc: 0.9036
# Epoch 3/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.2950 - acc: 0.9045 - val_loss: 0.3268 - val_acc: 0.8994
# Epoch 4/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.2806 - acc: 0.9056 - val_loss: 0.2720 - val_acc: 0.9059
# Epoch 5/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.2198 - acc: 0.9137 - val_loss: 0.1588 - val_acc: 0.9458
# Epoch 6/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.1528 - acc: 0.9463 - val_loss: 0.1240 - val_acc: 0.9632
# Epoch 7/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.1200 - acc: 0.9624 - val_loss: 0.1079 - val_acc: 0.9675
# Epoch 8/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.1091 - acc: 0.9666 - val_loss: 0.1140 - val_acc: 0.9567
# Epoch 9/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.1003 - acc: 0.9692 - val_loss: 0.1024 - val_acc: 0.9678
# Epoch 10/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.0915 - acc: 0.9709 - val_loss: 0.1038 - val_acc: 0.9675
# Epoch 11/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.0775 - acc: 0.9750 - val_loss: 0.0978 - val_acc: 0.9735
# Epoch 12/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0633 - acc: 0.9799 - val_loss: 0.0792 - val_acc: 0.9746
# Epoch 13/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0564 - acc: 0.9825 - val_loss: 0.0628 - val_acc: 0.9813
# Epoch 14/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0513 - acc: 0.9844 - val_loss: 0.0570 - val_acc: 0.9839
# Epoch 15/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.0466 - acc: 0.9858 - val_loss: 0.0543 - val_acc: 0.9837
# --- 634.5535016059875 seconds ---
# 15306/15306 [==============================] - 33s 2ms/sample
# accuracy  0.9839932052789756
# Matriz de confusión  [[13687    80]
#  [  165  1374]]
# Recall  0.8927875243664717
# Precision  0.9449793672627235
# F1-score  0.9181423321082525

# %%
vects=ListVect[1]
weights=ListWeig[1]
print("-------------Set {0}-------------".format(vects))
model=make_model(max_features)
(x_train, y_train),(x_test,y_test)=LoadData(vects,maxlen,max_features)  
tpu_model=trainModel(model,x_train,y_train,x_test,y_test,weights)
fpr,tpr=evaluate(x_test,y_test,model)
# Out:
# -------------Set /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet1_g1.pkl-------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 200)               0
# _________________________________________________________________
# Embedding (Embedding)        (None, 200, 128)          25600000
# _________________________________________________________________
# Bidirectional (Bidirectional (None, 400)               526400
# _________________________________________________________________
# Dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 401
# =================================================================
# Total params: 26,126,801
# Trainable params: 26,126,801
# Non-trainable params: 0
# _________________________________________________________________
# Train on 61224 samples, validate on 15306 samples
# Epoch 1/15
# 61224/61224 [==============================] - 100s 2ms/sample - loss: 0.3822 - acc: 0.8951 - val_loss: 0.3118 - val_acc: 0.9002
# Epoch 2/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.3073 - acc: 0.9026 - val_loss: 0.2948 - val_acc: 0.9055
# Epoch 3/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.2906 - acc: 0.9047 - val_loss: 0.2893 - val_acc: 0.9071
# Epoch 4/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.2654 - acc: 0.9082 - val_loss: 0.2512 - val_acc: 0.9128
# Epoch 5/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.2108 - acc: 0.9262 - val_loss: 0.3790 - val_acc: 0.8970
# Epoch 6/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.1550 - acc: 0.9450 - val_loss: 0.1461 - val_acc: 0.9603
# Epoch 7/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.1240 - acc: 0.9584 - val_loss: 0.1032 - val_acc: 0.9667
# Epoch 8/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.0974 - acc: 0.9683 - val_loss: 0.1248 - val_acc: 0.9620
# Epoch 9/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.0820 - acc: 0.9739 - val_loss: 0.0702 - val_acc: 0.9801
# Epoch 10/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0715 - acc: 0.9790 - val_loss: 0.0697 - val_acc: 0.9778
# Epoch 11/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0616 - acc: 0.9818 - val_loss: 0.0596 - val_acc: 0.9829
# Epoch 12/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0575 - acc: 0.9835 - val_loss: 0.0636 - val_acc: 0.9799
# Epoch 13/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.0539 - acc: 0.9842 - val_loss: 0.0604 - val_acc: 0.9815
# Epoch 14/15
# 61224/61224 [==============================] - 37s 612us/sample - loss: 0.0504 - acc: 0.9846 - val_loss: 0.0591 - val_acc: 0.9841
# Epoch 15/15
# 61224/61224 [==============================] - 37s 612us/sample - loss: 0.0476 - acc: 0.9864 - val_loss: 0.0577 - val_acc: 0.9840
# --- 635.0105919837952 seconds ---
# 15306/15306 [==============================] - 33s 2ms/sample
# accuracy  0.9841892068469881
# Matriz de confusión  [[13729    49]
#  [  193  1335]]
# Recall  0.8736910994764397
# Precision  0.9645953757225434
# F1-score  0.9168956043956044

# %%
vects=ListVect[2]
weights=ListWeig[2]
print("-------------Set {0}-------------".format(vects))
model=make_model(max_features)
(x_train, y_train),(x_test,y_test)=LoadData(vects,maxlen,max_features)  
tpu_model=trainModel(model,x_train,y_train,x_test,y_test,weights)
fpr,tpr=evaluate(x_test,y_test,model)
# Out:
# -------------Set /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet2_g1.pkl-------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 200)               0
# _________________________________________________________________
# Embedding (Embedding)        (None, 200, 128)          25600000
# _________________________________________________________________
# Bidirectional (Bidirectional (None, 400)               526400
# _________________________________________________________________
# Dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 401
# =================================================================
# Total params: 26,126,801
# Trainable params: 26,126,801
# Non-trainable params: 0
# _________________________________________________________________
# Train on 61224 samples, validate on 15306 samples
# Epoch 1/15
# 61224/61224 [==============================] - 99s 2ms/sample - loss: 0.3844 - acc: 0.8921 - val_loss: 0.3226 - val_acc: 0.9005
# Epoch 2/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.3381 - acc: 0.8961 - val_loss: 0.2960 - val_acc: 0.9045
# Epoch 3/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.2962 - acc: 0.9036 - val_loss: 0.2918 - val_acc: 0.9047
# Epoch 4/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.2800 - acc: 0.9043 - val_loss: 0.2102 - val_acc: 0.9251
# Epoch 5/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.2234 - acc: 0.9243 - val_loss: 0.1700 - val_acc: 0.9409
# Epoch 6/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.1305 - acc: 0.9570 - val_loss: 0.1154 - val_acc: 0.9652
# Epoch 7/15
# 61224/61224 [==============================] - 38s 613us/sample - loss: 0.1100 - acc: 0.9657 - val_loss: 0.1110 - val_acc: 0.9613
# Epoch 8/15
# 61224/61224 [==============================] - 37s 612us/sample - loss: 0.1028 - acc: 0.9679 - val_loss: 0.1133 - val_acc: 0.9652
# Epoch 9/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0975 - acc: 0.9695 - val_loss: 0.1017 - val_acc: 0.9691
# Epoch 10/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0897 - acc: 0.9713 - val_loss: 0.1067 - val_acc: 0.9661
# Epoch 11/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0805 - acc: 0.9736 - val_loss: 0.0822 - val_acc: 0.9724
# Epoch 12/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.0681 - acc: 0.9781 - val_loss: 0.0809 - val_acc: 0.9769
# Epoch 13/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0587 - acc: 0.9815 - val_loss: 0.0698 - val_acc: 0.9788
# Epoch 14/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0533 - acc: 0.9832 - val_loss: 0.0792 - val_acc: 0.9759
# Epoch 15/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0482 - acc: 0.9850 - val_loss: 0.0640 - val_acc: 0.9811
# --- 634.1460461616516 seconds ---
# 15306/15306 [==============================] - 33s 2ms/sample
# accuracy  0.9810531817587874
# Matriz de confusión  [[13712    72]
#  [  218  1304]]
# Recall  0.8567674113009198
# Precision  0.9476744186046512
# F1-score  0.8999309868875086

# %%
vects=ListVect[3]
weights=ListWeig[3]
print("-------------Set {0}-------------".format(vects))
model=make_model(max_features)
(x_train, y_train),(x_test,y_test)=LoadData(vects,maxlen,max_features)  
tpu_model=trainModel(model,x_train,y_train,x_test,y_test,weights)
fpr,tpr=evaluate(x_test,y_test,model)
# Out:
# -------------Set /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet3_g1.pkl-------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 200)               0
# _________________________________________________________________
# Embedding (Embedding)        (None, 200, 128)          25600000
# _________________________________________________________________
# Bidirectional (Bidirectional (None, 400)               526400
# _________________________________________________________________
# Dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 401
# =================================================================
# Total params: 26,126,801
# Trainable params: 26,126,801
# Non-trainable params: 0
# _________________________________________________________________
# Train on 61224 samples, validate on 15306 samples
# Epoch 1/15
# 61224/61224 [==============================] - 99s 2ms/sample - loss: 0.3822 - acc: 0.8919 - val_loss: 0.6470 - val_acc: 0.7733
# Epoch 2/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.3113 - acc: 0.9007 - val_loss: 0.3576 - val_acc: 0.9007
# Epoch 3/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.2938 - acc: 0.9042 - val_loss: 0.2811 - val_acc: 0.9051
# Epoch 4/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.2728 - acc: 0.9068 - val_loss: 0.2376 - val_acc: 0.9119
# Epoch 5/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.1954 - acc: 0.9331 - val_loss: 0.1562 - val_acc: 0.9464
# Epoch 6/15
# 61224/61224 [==============================] - 37s 611us/sample - loss: 0.1381 - acc: 0.9553 - val_loss: 0.1580 - val_acc: 0.9582
# Epoch 7/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.1219 - acc: 0.9610 - val_loss: 0.1177 - val_acc: 0.9635
# Epoch 8/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.1122 - acc: 0.9645 - val_loss: 0.1067 - val_acc: 0.9656
# Epoch 9/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.1009 - acc: 0.9679 - val_loss: 0.0965 - val_acc: 0.9701
# Epoch 10/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0883 - acc: 0.9713 - val_loss: 0.0880 - val_acc: 0.9694
# Epoch 11/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0763 - acc: 0.9751 - val_loss: 0.0727 - val_acc: 0.9757
# Epoch 12/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.0634 - acc: 0.9805 - val_loss: 0.0696 - val_acc: 0.9797
# Epoch 13/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0574 - acc: 0.9827 - val_loss: 0.0627 - val_acc: 0.9807
# Epoch 14/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.0520 - acc: 0.9849 - val_loss: 0.0646 - val_acc: 0.9804
# Epoch 15/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0488 - acc: 0.9857 - val_loss: 0.0691 - val_acc: 0.9802
# --- 633.8459322452545 seconds ---
# 15306/15306 [==============================] - 33s 2ms/sample
# accuracy  0.9801385077747289
# Matriz de confusión  [[13714    59]
#  [  245  1288]]
# Recall  0.8401826484018264
# Precision  0.9561989606533037
# F1-score  0.8944444444444444

# %%
vects=ListVect[4]
weights=ListWeig[4]
print("-------------Set {0}-------------".format(vects))
model=make_model(max_features)
(x_train, y_train),(x_test,y_test)=LoadData(vects,maxlen,max_features)  
tpu_model=trainModel(model,x_train,y_train,x_test,y_test,weights)
fpr,tpr=evaluate(x_test,y_test,model)
# Out:
# -------------Set /content/drive/My Drive/Colab Notebooks/DeteccionDeIronia/Experimento2/Vectores/vectoresSet4_g1.pkl-------------
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           (None, 200)               0
# _________________________________________________________________
# Embedding (Embedding)        (None, 200, 128)          25600000
# _________________________________________________________________
# Bidirectional (Bidirectional (None, 400)               526400
# _________________________________________________________________
# Dropout (Dropout)            (None, 400)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 401
# =================================================================
# Total params: 26,126,801
# Trainable params: 26,126,801
# Non-trainable params: 0
# _________________________________________________________________
# Train on 61224 samples, validate on 15306 samples
# Epoch 1/15
# 61224/61224 [==============================] - 99s 2ms/sample - loss: 0.3855 - acc: 0.8826 - val_loss: 0.3136 - val_acc: 0.8998
# Epoch 2/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.3151 - acc: 0.9015 - val_loss: 0.3024 - val_acc: 0.9023
# Epoch 3/15
# 61224/61224 [==============================] - 37s 610us/sample - loss: 0.2931 - acc: 0.9043 - val_loss: 0.2814 - val_acc: 0.9054
# Epoch 4/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.2804 - acc: 0.9050 - val_loss: 0.2659 - val_acc: 0.9094
# Epoch 5/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.2548 - acc: 0.9094 - val_loss: 0.2339 - val_acc: 0.9130
# Epoch 6/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.1900 - acc: 0.9323 - val_loss: 0.1360 - val_acc: 0.9578
# Epoch 7/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.1180 - acc: 0.9625 - val_loss: 0.0959 - val_acc: 0.9657
# Epoch 8/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0953 - acc: 0.9690 - val_loss: 0.0828 - val_acc: 0.9703
# Epoch 9/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0783 - acc: 0.9755 - val_loss: 0.0657 - val_acc: 0.9804
# Epoch 10/15
# 61224/61224 [==============================] - 37s 606us/sample - loss: 0.0645 - acc: 0.9802 - val_loss: 0.0650 - val_acc: 0.9773
# Epoch 11/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.0596 - acc: 0.9818 - val_loss: 0.1087 - val_acc: 0.9718
# Epoch 12/15
# 61224/61224 [==============================] - 37s 609us/sample - loss: 0.0546 - acc: 0.9837 - val_loss: 0.0705 - val_acc: 0.9759
# Epoch 13/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0504 - acc: 0.9847 - val_loss: 0.0657 - val_acc: 0.9806
# Epoch 14/15
# 61224/61224 [==============================] - 37s 607us/sample - loss: 0.0470 - acc: 0.9858 - val_loss: 0.0581 - val_acc: 0.9839
# Epoch 15/15
# 61224/61224 [==============================] - 37s 608us/sample - loss: 0.0442 - acc: 0.9867 - val_loss: 0.0576 - val_acc: 0.9834
# --- 633.2663836479187 seconds ---
# 15306/15306 [==============================] - 33s 2ms/sample
# accuracy  0.9833398667189337
# Matriz de confusión  [[13723    52]
#  [  203  1328]]
# Recall  0.8674069235793599
# Precision  0.9623188405797102
# F1-score  0.9124012366884232
